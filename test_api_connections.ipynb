# %% [markdown]
# <a href="https://colab.research.google.com/github/gptix/DS-Unit-3-Sprint-3-Productization-and-Cloud/blob/master/test_api_connections.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tweepy

# %%
# !pip install basilica

# %%
import tweepy, basilica

# %%
TWITTER_AUTH = tweepy.OAuthHandler(TWITTER_CONSUMER_KEY, TWITTER_CONSUMER_SECRET)
TWITTER_AUTH.set_access_token(TWITTER_ACCESS_TOKEN, TWITTER_ACCESS_TOKEN_SECRET)
TWITTER = tweepy.API(TWITTER_AUTH)
BASILICA =  basilica.Connection(BASILICA_KEY)

# %%
twitter_user = TWITTER.get_user('elonmusk')
twitter_user
# Out:
# User(_api=<tweepy.api.API object at 0x7fbf671f20b8>, _json={'id': 44196397, 'id_str': '44196397', 'name': 'Elon Musk', 'screen_name': 'elonmusk', 'location': '', 'profile_location': None, 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 30915005, 'friends_count': 82, 'listed_count': 53176, 'created_at': 'Tue Jun 02 20:12:29 +0000 2009', 'favourites_count': 4733, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 9817, 'lang': None, 'status': {'created_at': 'Wed Jan 29 19:52:57 +0000 2020', 'id': 1222608588134207488, 'id_str': '1222608588134207488', 'text': '@jeff_foust @SciGuySpace Ok, not so bad', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'jeff_foust', 'name': 'Jeff Foust', 'id': 6374602, 'id_str': '6374602', 'indices': [0, 11]}, {'screen_name': 'SciGuySpace', 'name': 'Eric Berger', 'id': 15726728, 'id_str': '15726728'
# ...

# %%
tweets = twitter_user.timeline()
tweets
# Out:
# [Status(_api=<tweepy.api.API object at 0x7fbf671f20b8>, _json={'created_at': 'Wed Jan 29 19:52:57 +0000 2020', 'id': 1222608588134207488, 'id_str': '1222608588134207488', 'text': '@jeff_foust @SciGuySpace Ok, not so bad', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'jeff_foust', 'name': 'Jeff Foust', 'id': 6374602, 'id_str': '6374602', 'indices': [0, 11]}, {'screen_name': 'SciGuySpace', 'name': 'Eric Berger', 'id': 15726728, 'id_str': '15726728', 'indices': [12, 24]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1222605882296545280, 'in_reply_to_status_id_str': '1222605882296545280', 'in_reply_to_user_id': 6374602, 'in_reply_to_user_id_str': '6374602', 'in_reply_to_screen_name': 'jeff_foust', 'user': {'id': 44196397, 'id_str': '44196397', 'name': 'Elon Musk', 'screen_name': 'elonmusk', 'location': '', 'description': '', 'url': None, 'entities
# ...

# %%
tweets[0].text
# Out:
# '@jeff_foust @SciGuySpace Ok, not so bad'

# %%
tweets = twitter_user.timeline(count=200, exclude_replies=True, include_rts=False, tweet_mode='extended')
tweets
# Out:
# [Status(_api=<tweepy.api.API object at 0x7fbf671f20b8>, _json={'created_at': 'Wed Jan 29 19:08:09 +0000 2020', 'id': 1222597315023654912, 'id_str': '1222597315023654912', 'full_text': 'A friend just sent me this excerpt from a Tesla blog I wrote 14 years ago https://t.co/Hr8w52ithY', 'truncated': False, 'display_text_range': [0, 73], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [], 'media': [{'id': 1222597312179884035, 'id_str': '1222597312179884035', 'indices': [74, 97], 'media_url': 'http://pbs.twimg.com/media/EPeJxx_UUAMJQJP.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EPeJxx_UUAMJQJP.jpg', 'url': 'https://t.co/Hr8w52ithY', 'display_url': 'pic.twitter.com/Hr8w52ithY', 'expanded_url': 'https://twitter.com/elonmusk/status/1222597315023654912/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 1096, 'h': 565, 'resize': 'fit'}, 'medium': {'w': 1096, 'h': 565, 'resize': 'fit'}, 'small': {'w': 680, 'h'
# ...

# %%
len(tweets)
# Out:
# 34

# %%
tweets[2].full_text
# Out:
# 'Chairs are underappreciated'

# %%
embedding = BASILICA.embed_sentence(tweets[0].full_text, model='twitter')
embedding

# %%
def add_user(username):
  # Get twitter user data via tweepy API
  twitter_usder = TWITTER.get_user(username)

  # Ad user info to user table in database
  db_user = User(id=twitter_user.id, name=twitter_user.screen_name)

  # if more fields of data are desired, make sure to change the class definition
  # in models.py, then delete the extant db, then fun flask shell, then import 
  # models, then run DB.create_all()

  # finish add_user function
